# %% [markdown]
# # Exercise 1 (4 points)
#
# Which prescriptive method is considered the most widely used according to the literature?
#
# - (a) Machine learning
# - (b) Mathematical programming
# - (c) Simulations
# - (d) Decision trees
# - (e) None of the above

# %% [markdown]
# (b)

# %% [markdown]
# # Exercise 2 (4 points)
#
# Briefly describe the difference between stochastic and non-stochastic prescriptive methods.

# %% [markdown]
# Non-stochastic methods do not directly incorporate randomness and focus on deterministic processes (e.g., mathematical programming). Stochastic methods explicitply account for random variations, such as Monte Carlo simulations or probabilistic modeling.

# %% [markdown]
# # Exercise 3 (4 points)
#
# Which of the following is NOT one of the six categories of prescriptive methods outlined by Lepeniotia et al. (2020)?
#
# - (a) Mathematical programming
# - (b) Evolutionary computation
# - (c) Heuristic-based guessing
# - (d) Logic-based methods
# - (e) None of the above

# %% [markdown]
# (c)

# %% [markdown]
# # Exercise 4 (10 points)
#
# Consider the `train.csv` data file. This data file contains information related to music tracks. The goal is to build a machine learning model to predict `BeatsPerMinute`. Explore the data.

# %%
import pandas as pd 
import matplotlib.pyplot as plt

df = pd.read_csv("train.csv", index_col=0)
df.head()
# Out:
#     RhythmScore  AudioLoudness  VocalContent  AcousticQuality  \
# id
# 0      0.603610      -7.636942      0.023500         0.000005
# 1      0.639451     -16.267598      0.071520         0.444929
# 2      0.514538     -15.953575      0.110715         0.173699
# 3      0.734463      -1.357000      0.052965         0.001651
# 4      0.532968     -13.056437      0.023500         0.068687
#
#     InstrumentalScore  LivePerformanceLikelihood  MoodScore  TrackDurationMs  \
# id
# 0            0.000001                   0.051385   0.409866      290715.6450
# 1            0.349414                   0.170522   0.651010      164519.5174
# 2            0.453814                   0.029576   0.423865      174495.5667
# 3            0.159717                   0.086366   0.278745      225567.4651
# 4            0.000001                   0.331345   0.477769      213960.6789
#
#       Energy  BeatsPerMinute
# id
# 0   0.826267       147.53020
# 1   0.145400       136.15963
# ...

# %%
plt.hist(df['BeatsPerMinute'], bins=20, edgecolor='black', color="steelblue")
plt.xlabel('Beats Per Minute')
plt.ylabel('Frequency')
plt.title('Distribution of Beats Per Minute')
plt.grid()
plt.show()

# %% [markdown]
# The `BeatsPerMinute` distribution looks symmetrical and normally distributed.

# %%
plt.plot(df["Energy"], df['BeatsPerMinute'], 'o', color="steelblue")
plt.xlabel('Energy')
plt.ylabel('Beats Per Minute')
plt.title('Beats Per Minute vs Energy')
plt.grid()
plt.show()
